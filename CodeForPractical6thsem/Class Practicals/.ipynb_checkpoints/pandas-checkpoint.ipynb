# %%
import pandas as pd
series=pd.Series([1, 2, 3, 4, 5],dtype=float,index=["a", "b", "c", "d", "e"])
print(series)
range = pd.Series(range(10))
print(range)
dict = pd.Series({'a': 1, 'b': 2, 'c': 3})
print(dict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import pandas as pd
#       2 pd.Series([1, 2, 3, 4, 5],dtype=float,index=["a", "b", "c", "d", "e"])
#
# File ~\OneDrive\Documents\Semester 6 Lab Manual\Machine Learning\pandas.py:2, in <module>
#       1 import pandas as pd
# ----> 2 series = pd.Series([1, 2, 3, 4, 5], index=["a", "b", "c", "d", "e"])
#       3 print(series)
#       4 range = pd.Series(range(10))
#
# AttributeError: partially initialized module 'pandas' has no attribute 'Series' (most likely due to a circular import)
